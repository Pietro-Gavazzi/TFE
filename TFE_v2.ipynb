# %%
import numpy as np
from numpy.linalg import inv, pinv, norm

def generate_linear_weight(input_size, hidden_layer_size_list, output_size, epsilon):
    nb_elements = 0
    previous_size = 0
    for next_size in hidden_layer_size_list:
        nb_elements += previous_size*next_size
        previous_size = next_size
    nb_elements += previous_size*output_size

    prob = 0.01

    sigma = np.sqrt ((epsilon*prob)/(7*nb_elements))
    print(f"sigma is {sigma}")

    weight_list = []
    previous_size = input_size

    zeros= 0
    for next_size in hidden_layer_size_list:
        weight_list.append(np.random.random(size = (previous_size, next_size))*sigma*zeros)
        previous_size = next_size
        zeros = (zeros or 1)
        # print(f"zeros is {zeros}")
    
    weight_list.append((np.random.random(size = (previous_size, next_size))*sigma).T[0].reshape((previous_size, 1)))

    return weight_list


class LinearModel():
    def __init__(self, input_size, hidden_layer_size_list, output_size, epsilon=1):
        self.input_size= input_size
        # Initialize the weights
        self.weight_list = generate_linear_weight(input_size, hidden_layer_size_list, output_size, epsilon) 

    def __call__(self, X):
        return self.forward(X)
    


    def step(self, X_train, y_train, lr=0.01):
        # Forward pass
        y_pred = self.forward(X_train)
        N = X_train.shape[0]

        # Compute gradient of loss w.r.t. output
        dA = (2 / N) * (y_pred - y_train)   # dL/dA_last

        # List to store gradients for each weight matrix
        grad_list = [None] * len(self.weight_list)

        # Backward pass: reverse order
        for i in reversed(range(len(self.weight_list))):
            W = self.weight_list[i]

            # a_{i-1} is either input X or previous partial output
            if i == 0:
                A_prev = self.lastX
            else:
                A_prev = self.partial[i-1]

            # Gradient wrt W_i:   dW = A_prev.T @ dA
            grad_W = A_prev.T @ dA
            grad_list[i] = grad_W

            # Backprop to previous layer: dA = dA @ W.T
            dA = dA @ W.T

        # Update parameters
        for i in range(len(self.weight_list)):
            self.weight_list[i] -= lr * grad_list[i]


    def get_w_prod(self):
        w_prod = self.weight_list[0]
        for i in range(1, len(self.weight_list)):
            w_prod = w_prod@self.weight_list[i]
        return w_prod
    
    def forward(self, X):
        if X.shape[1] != self.input_size:
            print("size of input do not match size of model")
            return
        
        self.lastX = X
        y = X

        self.partial = []
        for W in self.weight_list:
            y = y@W
            self.partial.append(y)
        return y



def generate_data(n, d, noise_variance = .1):
    """Generates random Gaussian data with noise."""
    X = np.random.normal(0, 1, (n, d))
    Xtest = np.random.normal(0, 1, (n, d))
    w_true = np.random.normal(0, 1, (d,1))
    noise = np.random.normal(0, 1, (n, 1))
    y = X @ w_true + noise_variance * noise
    noise2 = np.random.normal(0, 1, (n,1))
    ytest = Xtest @ w_true + noise_variance * noise2
    w_star = np.linalg.pinv(X.T @ X) @ X.T @ y
    return (X, y, Xtest, ytest, w_star, w_true)

# %%
y = [ 0 0 ]
    [ 0 1 ]

y_hat  = x*w1*w2*w3

w1 = [1]
     [0.1]

w2 = [0]

w3 = [1, -0.1]


W1 W3 = [1, 0]
        [0, 0]

# %%
    
np.random.seed(45)
n = 4
d = 6


# 2*2, 2 matrices, voir les vecteurs s'aligner, qu'est ce qu'il se passe pendant 


model = LinearModel(d, [ d, d, d], 1)
for weight in model.weight_list:
    print(np.linalg.svd(weight)[1][0])

(X, y, Xtest, ytest, w_star, w_true) =  generate_data(n, d, noise_variance=10)

col_Xt_proj_mat = X.T@pinv(X@X.T)@X
kern_X_proj_mat = np.eye(d) - col_Xt_proj_mat

best_error = (norm(y-X@w_star))

w_0 = model.get_w_prod()

test_error = []
val_col = []
val_ker = []
dif_w_star = []

test_error.append(norm(y-model(X)))
val_col.append(norm(col_Xt_proj_mat@w_0))
val_ker.append(norm(kern_X_proj_mat@w_0))
dif_w_star.append(norm(w_0-w_star))

nb_steps = 2000000
for i in range(nb_steps):
    # print(model(X))
    # print(i)
    model.step(X, y, .001)
    w_0 = model.get_w_prod()


    if i%(nb_steps/100) == 0:
        test_error.append(norm(y-model(X)))
        val_col.append(norm(col_Xt_proj_mat@w_0))
        val_ker.append(norm(kern_X_proj_mat@w_0))
        dif_w_star.append(norm(w_0-w_star))
        print(np.log(test_error[-1]))

print ()
print(test_error[0])
print(test_error[-1])
print ()
for weight in model.weight_list:
    print(np.linalg.svd(weight)[1][0])
# Out:
# sigma is 0.004279604925109129
# 0.0
# 0.011996694690312545
# 0.01488265529475689
# 0.005820198905134835
# 2.835055863235772
# 2.835055863198643
# 2.8350558631606613
# 2.8350558631209384
# 2.8350558630785097
# 2.835055863032287
# 2.8350558629810054
# 2.8350558629231464
# 2.8350558628568407
# 2.8350558627797335
# 2.8350558626887885
# 2.8350558625800066
# 2.8350558624480064
# 2.8350558622853743
# 2.8350558620816413
# 2.8350558618216097
# 2.8350558614825054
# 2.8350558610289243
# 2.8350558604033607
# 2.835055859507301
# 2.8350558581603695
# 2.8350558560027475
# 2.835055852229076
# 2.835055844715782
# 2.835055826234493
# 2.8350557574282305
# 2.835054790815246
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
# -31.231237743471326
#
# 17.03135170023738
# 2.731780401750985e-14
#
# 1.7203226935624227
# 1.7171837485609105
# 1.7172054117173328
# 1.7171523285619867

# %%
import matplotlib.pyplot as plt
print(test_error)

plt.title("Error VS Best error")
plt.plot(test_error)
plt.plot([best_error for _ in range(len(test_error)) ])
# plt.ylim(0, best_error*2)
plt.show()

plt.title("col variance VS kern variance")
plt.plot(val_col)
# print(val_col)
plt.plot(val_ker)
# print(val_ker)
plt.show()

plt.title("Norm of the difference of the model frow least squares solution")
plt.plot(dif_w_star)
plt.yscale('log')

# print(w_0-w_star)
# print(model.weight_list)
# Out:
# [17.03135170023738, 17.03135170023735, 17.031351699604993, 17.03135169895812, 17.031351698281583, 17.03135169755896, 17.031351696771733, 17.031351695898334, 17.031351694912917, 17.031351693783645, 17.031351692470402, 17.031351690921483, 17.031351689068785, 17.031351686820642, 17.031351684050797, 17.03135168058095, 17.03135167615226, 17.031351670376853, 17.031351662651755, 17.03135165199756, 17.031351636736453, 17.031351613796392, 17.03135157704917, 17.031351512778443, 17.031351384816894, 17.031351070055567, 17.031349898191994, 17.031333435476004, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14, 2.731780401750985e-14]

# %%
print ("Here are ")
for weight in model.weight_list:
    svd_decomp = np.linalg.svd(weight)
    print(f"highest left singular vectior: {svd_decomp[0].T[0]}")
    print(f"highest singular vaule: {svd_decomp[1][0]}")
    print(f"highest right singular vector: {svd_decomp[2][0]}")
    print()

print (model.get_w_prod())
print(w_star)
# Out:
# Here are
# highest left singular vectior: [-0.47520477 -0.0893939   0.69110005 -0.03109486  0.0776144  -0.53064017]
# highest singular vaule: 1.7203226935624227
# highest right singular vector: [0.35630849 0.47386761 0.45255169 0.40083397 0.42732886 0.31687993]
#
# highest left singular vectior: [-0.35630876 -0.47386821 -0.45255259 -0.40083179 -0.42732903 -0.31687997]
# highest singular vaule: 1.7171837485609105
# highest right singular vector: [-0.47128977 -0.27413955 -0.40049259 -0.40387246 -0.49543438 -0.36574711]
#
# highest left singular vectior: [-0.47128901 -0.27413891 -0.40050764 -0.40387338 -0.49542377 -0.36574548]
# highest singular vaule: 1.7172054117173328
# highest right singular vector: [-0.47167716 -0.20477934 -0.26134264 -0.52169781 -0.49946412 -0.38164524]
#
# highest left singular vectior: [0.47167358 0.20477321 0.2613345  0.52170586 0.49947081 0.38163877]
# highest singular vaule: 1.7171523285619867
# highest right singular vector: [1.]
#
# [[-4.13941099]
#  [-0.77869191]
#  [ 6.02003043]
#  [-0.27086095]
#  [ 0.67608307]
#  [-4.62229737]]
# [[-4.13941099]
#  [-0.77869191]
#  [ 6.02003043]
#  [-0.27086095]
#  [ 0.67608307]
#  [-4.62229737]]

# %%
y_hat = X W1 W2 ... WL
X.T(y_ha-y) WL.T ... W2.T
# Out:
#   Cell In [60], line 1
#     y_hat = X W1 W2 ... WL
#               ^
# SyntaxError: invalid syntax

# %%
def grad_R_1():
    return -(2/n)*X.T(y-X@w_true) 


W = [Wi for i in range(L)]


def f_linear_deep(x, k):
    return

# %%
class LinearFullyConnectedNoBiasNet(nn.Module):
    def __init__(self, input_size, hidden_layer_size_list, output_size):
        super(LinearFullyConnectedNoBiasNet, self).__init__()
        
        layers = []
        in_size = input_size
        
        # Hidden layers (no bias)
        for hidden_size in hidden_layer_size_list:
            linear = nn.Linear(in_size, hidden_size, bias=False)   # <-- no bias
            init.normal_(linear.weight, mean=0.0, std=0.1)
            layers.append(linear)
            in_size = hidden_size
        
        # Output layer (no bias)
        linear = nn.Linear(in_size, output_size, bias=False)       # <-- no bias
        init.normal_(linear.weight, mean=0.0, std=0.0)
        layers.append(linear)
        
        # Sequential model
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        x = x.view(x.size(0), -1)
        return self.net(x)



# --- Neural Network ---
class LinearFullyConnectedNet(nn.Module):
    def __init__(self, input_size, hidden_layer_size_list, output_size):
        super(LinearFullyConnectedNet, self).__init__()
        
        # Create a list to hold all layers
        layers = []
        in_size = input_size
        
        for hidden_size in hidden_layer_size_list:
            linear = nn.Linear(in_size, hidden_size)
            init.normal_(linear.weight, mean=0.0, std=0.1)   # <--- weight distribution
            init.zeros_(linear.bias)
            layers.append(linear)
            in_size = hidden_size
        
        linear = nn.Linear(in_size, output_size)
        init.normal_(linear.weight, mean=0.0, std=0.0)       # <--- output layer weights
        init.zeros_(linear.bias)
        layers.append(linear)        
        self.net = nn.Sequential(*layers)
        
        # Wrap layers into a sequential module
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten input
        x = self.net(x)            # Forward pass through linear layers
        return x



def generate_data(n, d, noise_variance):
    """Generates random Gaussian data with noise."""
    X = np.random.normal(0, 1, (n, d))
    Xtest = np.random.normal(0, 1, (n, d))
    w_true = np.random.normal(0, 1, (d,1))
    noise = np.random.normal(0, 1, (n, 1))
    y = X @ w_true + noise_variance * noise
    noise2 = np.random.normal(0, 1, (n,1))
    ytest = Xtest @ w_true + noise_variance * noise2
    w_star = np.linalg.pinv(X.T @ X) @ X.T @ y
    norm_factor = np.linalg.norm(w_star)
    w_star = w_star / norm_factor
    y = y / norm_factor
    ytest = ytest / norm_factor
    return (X, y, Xtest, ytest, w_star)

# %%
# Learning rate Number of steps Number of repetitions
# 0.001 40, 000 100
# 0.004 10, 000 20
# 0.01 4, 000 20

# Assuming your classes FullyConnectedNet, LinearFullyConnectedNet, and generate_data are already defined

loss_list = [0 for _ in range(5)]
for i in range(200):
    # --- Generate data ---
    n_samples = 15
    n_features = 20
    noise_var = 0.1

    X_train, y_train, X_test, y_test, w_star = generate_data(n_samples, n_features, noise_var)

    # Convert to torch tensors
    X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
    X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
    y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

    for np_hidden_layer in range(5):
        # --- Hyperparameters ---
        input_size = n_features
        hidden_layers = [n_features for _ in range (np_hidden_layer)]
        output_size = 1
        learning_rate = 0.01
        num_epochs = 4000

        # --- Initialize networks ---
        linear_model = LinearFullyConnectedNoBiasNet(input_size, hidden_layers, output_size)

        # --- Loss and optimizer ---
        criterion = nn.MSELoss()
        linear_optimizer = optim.SGD(linear_model.parameters(), lr=learning_rate)

        # --- Training function ---
        def train(model, optimizer, X, y):
            for epoch in range(num_epochs):
                optimizer.zero_grad()
                outputs = model(X)
                loss = criterion(outputs, y)
                loss.backward()
                optimizer.step()
                # if (epoch + 1) % 50 == 0:
                #     print(f"Epoch {epoch+1}/{num_epochs}, Loss: {loss.item():.6f}")
            return model

        # --- Train Linear Model ---
        print("Training Linear Model:")
        linear_model = train(linear_model, linear_optimizer, X_train_tensor, y_train_tensor)


        # --- Evaluate ---
        def evaluate(model, X, y):
            with torch.no_grad():
                y_pred = model(X)
                mse = criterion(y_pred, y)
            return mse.item()

        linear_mse = evaluate(linear_model, X_test_tensor, y_test_tensor)
        loss_list[np_hidden_layer]+= linear_mse

        print(f"\nTest MSE Linear Model {np_hidden_layer} hidden layers: {linear_mse:.6f}")

print(loss_list)
# Out:
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.523012
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.381292
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.287648
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.362810
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.699511
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.481280
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.447548
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.327757
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.529418
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.482087
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.315914
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.259519
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.290579
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.270312
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.479338
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.427430
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.414691
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.432323
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.473182
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.523328
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.077116
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.021204
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.060248
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.249223
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.100596
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.725053
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.858673
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.657628
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.868749
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.563055
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.296019
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.210558
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.340744
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.398243
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.160894
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.571148
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.447647
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.349313
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.734493
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.438007
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.442979
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.351803
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.627754
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.564603
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.819221
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.254819
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.281786
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.191948
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.588506
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.263841
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.245240
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.382053
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.186416
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.237085
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.361092
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.480167
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.412587
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.433320
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.587032
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.602515
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.135581
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.336071
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.142420
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.279093
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.145324
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.335074
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.243813
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.359477
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.145494
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.420221
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.489003
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.364175
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.318263
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.525692
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.388612
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.522199
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.572710
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.857813
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.811197
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.333366
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.181941
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.236732
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.110717
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.470291
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.452905
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.442993
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.644967
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.488806
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.386398
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.413225
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.294119
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.145389
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.248340
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.135976
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.182965
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.095430
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.079687
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.144232
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.126066
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.165758
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.052603
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.506936
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.337321
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.613269
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.479587
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.389307
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.150242
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.307945
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.238793
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.250091
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.151726
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.446703
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.321165
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.505134
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.331265
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.374701
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.328926
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.252550
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.368319
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.177826
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.298811
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.870937
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.908107
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 1.131387
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 1.101985
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.843851
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.102266
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.129566
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.130931
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.315796
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.163716
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.166709
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.244251
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.224528
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.183556
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.111605
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.497343
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.835650
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.962202
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.306348
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.609947
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.324108
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.474549
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.486476
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.617889
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.270748
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.689579
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.677286
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 1.071102
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.651765
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.541611
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.218311
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.205666
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.217465
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.249342
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.221242
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.337134
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.273417
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.305170
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.355533
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.187425
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.307853
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.478300
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.401098
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.372382
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.279690
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.175263
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.265106
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.095754
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.158572
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.196069
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.115110
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.160141
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.178286
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.257414
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.118655
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.129992
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.220443
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.131219
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.150831
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.160425
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.435923
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.246386
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.586319
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.686848
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.441914
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.330564
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.287521
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.288800
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.347819
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.340879
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.091879
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.142329
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.132472
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.168132
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.109694
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.069891
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.182484
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.071184
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.253926
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.255803
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.042938
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.053024
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.100504
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.102016
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.049335
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.083879
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.246108
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.307647
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.214789
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.130405
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.077389
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.047964
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.188941
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.060592
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.044729
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.451441
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.311891
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.461278
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.400077
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.660191
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 1.052508
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.969749
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 1.193956
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 1.477027
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.802460
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.862356
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 1.136266
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 1.332968
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 1.456309
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.781724
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.332531
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.235730
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.452162
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.454132
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.587963
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.490738
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.522204
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.620957
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.315042
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.710362
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.874629
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.739954
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.868778
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.822926
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.716314
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 1.169367
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 1.331586
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 1.386026
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 1.625713
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.808152
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.162560
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.427423
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.164886
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.134943
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.320572
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.275329
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.470012
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.501982
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.244573
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.288682
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.174237
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.173805
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.149445
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.169655
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.297435
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.303641
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.306728
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.271955
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.348662
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.560774
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.330826
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.445823
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.906843
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.257521
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.355610
# Training Linear Model:
#
# Test MSE Linear Model 0 hidden layers: 0.251175
# Training Linear Model:
#
# Test MSE Linear Model 1 hidden layers: 0.246814
# Training Linear Model:
#
# Test MSE Linear Model 2 hidden layers: 0.591927
# Training Linear Model:
#
# Test MSE Linear Model 3 hidden layers: 0.214423
# Training Linear Model:
#
# Test MSE Linear Model 4 hidden layers: 0.214900
# [71.90419388189912, 81.10373154655099, 82.87321507930756, 81.21032679080963, 78.89492134004831]

# %%
# [9.702300906181335, 11.642261669039726, 12.057800024747849, 9.821201026439667, 11.0854582041502] -> 5
# [2.9719553887844086, 3.8727946877479553, 2.33234041929245, 3.175804942846298, 3.268315553665161] -> 5 zerowing last layer
# [0.9575713351368904, 1.1555967703461647, 0.9533673599362373, 1.4852095395326614, 0.840996690094471] -> 5 zerowing last layer no bias


# [109.4951546844095, 110.53674245066941, 114.37919862940907, 117.56160471960902, 116.44494522362947] -> 200
# [93.15318554639816, 107.99330313503742, 109.18924476392567, 117.36815650388598, 119.19686833024025] -> 200 zerowing last layer
# [71.90419388189912, 81.10373154655099, 82.87321507930756, 81.21032679080963, 78.89492134004831] -> 200 zerowing last layer no bias
